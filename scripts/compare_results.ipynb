# %%
import pandas as pd

df1 = pd.read_csv("results/logisitc_by_msa.csv", index_col = 0)
df1 = df1.drop(columns = ["index"])

df2 = pd.read_csv("results/logistic_by_zipcode.csv", index_col = 0)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 3
#       1 import pandas as pd
# ----> 3 df1 = pd.read_csv("results/logisitc_by_msa.csv", index_col = 0)
#       4 df1 = df1.drop(columns = ["index"])
#       6 df2 = pd.read_csv("results/logistic_by_zipcode.csv", index_col = 0)
#
# ...

# %%
df1.head()
# Out:
#    zip_code  income_2030  rent_2030  college_2030  \
# 0       602        19337       3931          22.6
# 1       603        19302       8080          23.7
# 2       610        21663       2816          16.6
# 3       631        14914        373          16.6
# 4       662        18862       7203          19.4
#
#                                   msa_name  gentrification_prob_2035
# 0  Aguadilla-Isabela-San Sebastian, PR MSA                  0.508726
# 1  Aguadilla-Isabela-San Sebastian, PR MSA                  0.497679
# 2  Aguadilla-Isabela-San Sebastian, PR MSA                  0.524413
# 3  Aguadilla-Isabela-San Sebastian, PR MSA                  0.506732
# 4  Aguadilla-Isabela-San Sebastian, PR MSA                  0.501753

# %%
df2.head()
# Out:
#    zip_code  income_2012  income_2013  income_2014  income_2015  income_2016  \
# 0       602      15106.0      15663.0      16353.0      16079.0      15511.0
# 1       603      15079.0      15485.0      16323.0      16804.0      16681.0
# 2       610      16923.0      16707.0      17265.0      17475.0      17751.0
# 3       612      18111.0      17848.0      17752.0      17229.0      17208.0
# 4       616      16279.0      15342.0      15115.0      13705.0      14490.0
#
#    income_2017  income_2018  income_2019  income_2020  ...  \
# 0      16190.0      16358.0      16807.0      16771.0  ...
# 1      16645.0      16603.0      16049.0      15786.0  ...
# 2      18741.0      19309.0      19898.0      20167.0  ...
# 3      17744.0      18171.0      18741.0      19402.0  ...
# 4      14918.0      16018.0      17007.0      18903.0  ...
#
#    median_contract_rent_2018  median_contract_rent_2019  \
# 0                     3257.0                     3212.0
# ...
